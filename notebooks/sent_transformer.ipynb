# %%
import os 
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from tqdm import tqdm
from sklearn.linear_model import LogisticRegression
# !pip install sentence_transformers
from sentence_transformers import SentenceTransformer




CODE_PATH = os.getcwd()
BASE_PATH = os.path.abspath(os.path.join(CODE_PATH, ".."))
DATA_PATH = os.path.join(BASE_PATH, "Data")
os.chdir(BASE_PATH)

# %% [markdown]
# ## Load Data

# %%
#load data
data = pd.read_csv(os.path.join(DATA_PATH, 'Reviews.csv'))
data.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
#select useful columns
cols = ['ProductId', 'UserId', 'Score', 'Text']
select_data = data[cols]
select_data.head()
# Out:
#     ProductId          UserId  Score  \
# 0  B001E4KFG0  A3SGXH7AUHU8GW      5
# 1  B00813GRG4  A1D87F6ZCVE5NK      1
# 2  B000LQOCH0   ABXLMWJIXXAIN      4
# 3  B000UA0QIQ  A395BORC6FGVXV      2
# 4  B006K2ZZ7K  A1UQRSCLF8GW1T      5
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %% [markdown]
# ## Preprocess Data

# %% [markdown]
# ### Label Sentiment

# %%
#visulize the distribution of scores
plt.hist(select_data["Score"])
plt.show()

# %%
#split the data
train_data, test_data = train_test_split(select_data, random_state=0, test_size=0.3)

# %%
sentiment_label = {1: "positive",
                 0: "neutral",
                 -1: "negative"}
def label_sentiment(data):
    data.loc[data['Score'] == 5, ["sentiment"]] = 1
    data.loc[data['Score'] == 4, ["sentiment"]] = 0
    data.loc[data['Score'] <= 3, ["sentiment"]] = -1
    return data

# %%
train_data = label_sentiment(train_data)
test_data = label_sentiment(test_data)
train_data.head()
# Out:
#          ProductId          UserId  Score  \
# 333546  B00188S3PM  A3IMFBFX5L85S9      2
# 149769  B00004S1C5  A1KXONFPU2XQ5K      5
# 483649  B000LKTW5S  A2CH3AVJI0UR3P      5
# 392300  B001EQ50U4   AKP5H95MFKI21      4
# 1514    B003UIDAHY   A5WOFSMP2PI45      5
#
#                                                      Text  sentiment
# 333546  I had a hard time drinking this tea as it tast...       -1.0
# 149769  This are so much easier to use than the Wilson...        1.0
# 483649  I've had a bunch of these Indian food pouch th...        1.0
# 392300  I received this item as advertised, i.e. pack ...        0.0
# 1514    Great product.  Recommended by Dr. Oz.  We lov...        1.0

# %% [markdown]
# ## Create document embeddings

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# Load pre-trained model
senttrans_model = SentenceTransformer('all-MiniLM-L6-v2',device=device)

# Create embeddings for training set text
X_train = train_data['Text'].values.tolist()
X_train = [senttrans_model.encode(doc) for doc in X_train]

# Create embeddings for test set text
X_test = test_data['Text'].values.tolist()
X_test = [senttrans_model.encode(doc) for doc in X_test]
# Out:
# Downloading: 100%|██████████| 1.18k/1.18k [00:00<00:00, 587kB/s]
# Downloading: 100%|██████████| 10.2k/10.2k [00:00<00:00, 5.09MB/s]
# Downloading: 100%|██████████| 612/612 [00:00<00:00, 306kB/s]
# Downloading: 100%|██████████| 116/116 [00:00<00:00, 58.0kB/s]
# Downloading: 100%|██████████| 39.3k/39.3k [00:00<00:00, 1.05MB/s]
# Downloading: 100%|██████████| 349/349 [00:00<00:00, 349kB/s]
# Downloading: 100%|██████████| 90.9M/90.9M [00:06<00:00, 14.1MB/s]
# Downloading: 100%|██████████| 53.0/53.0 [00:00<00:00, 23.5kB/s]
# Downloading: 100%|██████████| 112/112 [00:00<00:00, 112kB/s]
# Downloading: 100%|██████████| 466k/466k [00:00<00:00, 3.01MB/s]
# Downloading: 100%|██████████| 350/350 [00:00<00:00, 173kB/s]
# Downloading: 100%|██████████| 13.2k/13.2k [00:00<00:00, 7.54MB/s]
# Downloading: 100%|██████████| 232k/232k [00:00<00:00, 1.88MB/s]
# Downloading: 100%|██████████| 190/190 [00:00<00:00, 95.0kB/s]

# %% [markdown]
# ## Train classification model

# %%
# Train a classification model using logistic regression classifier
y_train = train_data['sentiment']
logreg_model = LogisticRegression(solver='saga')
logreg_model.fit(X_train,y_train)
preds = logreg_model.predict(X_train)
acc = sum(preds==y_train)/len(y_train)
print('Accuracy on the training set is {:.3f}'.format(acc))
# Out:
# Accuracy on the training set is 0.739

# %% [markdown]
# ## Evaluate model performance

# %%
# Evaluate performance on the test set
y_test = test_data['sentiment']
preds = logreg_model.predict(X_test)
acc = sum(preds==y_test)/len(y_test)
print('Accuracy on the test set is {:.3f}'.format(acc))
# Out:
# Accuracy on the test set is 0.737

# %%
train_data['sentiment_pred'] = logreg_model.predict(X_train)
test_data['sentiment_pred'] = logreg_model.predict(X_test)

# %%
train_data.head()
# Out:
#          ProductId          UserId  Score  \
# 333546  B00188S3PM  A3IMFBFX5L85S9      2
# 149769  B00004S1C5  A1KXONFPU2XQ5K      5
# 483649  B000LKTW5S  A2CH3AVJI0UR3P      5
# 392300  B001EQ50U4   AKP5H95MFKI21      4
# 1514    B003UIDAHY   A5WOFSMP2PI45      5
#
#                                                      Text  sentiment  \
# 333546  I had a hard time drinking this tea as it tast...       -1.0
# 149769  This are so much easier to use than the Wilson...        1.0
# 483649  I've had a bunch of these Indian food pouch th...        1.0
# 392300  I received this item as advertised, i.e. pack ...        0.0
# 1514    Great product.  Recommended by Dr. Oz.  We lov...        1.0
#
#         sentiment_pred
# 333546             1.0
# 149769             1.0
# 483649             1.0
# 392300            -1.0
# 1514               1.0

# %%
train_data.to_csv(os.path.join(DATA_PATH, "transformer_train.csv"))
test_data.to_csv(os.path.join(DATA_PATH, "transformer_test.csv"))

# %%
train_data = pd.read_csv(os.path.join(DATA_PATH, "transformer_train.csv"))
test_data = pd.read_csv(os.path.join(DATA_PATH, "transformer_test.csv"))

# %%
#compute the average sentiment for each user and product
user_sent = train_data.groupby(['UserId'])['sentiment'].agg(['count', 'mean']).reset_index()
prod_sent = train_data.groupby(['ProductId'])['sentiment'].agg(['count', 'mean']).reset_index()

# %%
#visulize the distribution of sentiment
import matplotlib.pyplot as plt
plt.hist(user_sent['mean'])
plt.show()

# %%
def create_bins(data):
    #group the sentiment into bins according to its quantile
    n = 20
    q = [i/n for i in range(1, n)]
    quant = data['mean'].quantile(q)

    #create bins
    bins = list(set(quant))
    bins.sort(reverse=True)

    #map bins with sentiment
    data['bin_sent'] = len(bins)
    for i in range(len(bins)-1):
        idx = (data['mean'] < bins[i]) & (data['mean'] >= bins[i+1])
        data.loc[idx, ['bin_sent']] = len(bins) - i - 1
    
    return data

# %%
user_sent_bin = create_bins(user_sent)[['UserId', 'bin_sent']]
prod_sent_bin = create_bins(prod_sent)[['ProductId', 'bin_sent']]

# %%
train_data.head()
# Out:
#    Unnamed: 0   ProductId          UserId  Score  \
# 0      333546  B00188S3PM  A3IMFBFX5L85S9      2
# 1      149769  B00004S1C5  A1KXONFPU2XQ5K      5
# 2      483649  B000LKTW5S  A2CH3AVJI0UR3P      5
# 3      392300  B001EQ50U4   AKP5H95MFKI21      4
# 4        1514  B003UIDAHY   A5WOFSMP2PI45      5
#
#                                                 Text  sentiment  \
# 0  I had a hard time drinking this tea as it tast...       -1.0
# 1  This are so much easier to use than the Wilson...        1.0
# 2  I've had a bunch of these Indian food pouch th...        1.0
# 3  I received this item as advertised, i.e. pack ...        0.0
# 4  Great product.  Recommended by Dr. Oz.  We lov...        1.0
#
#    sentiment_pred
# 0             1.0
# 1             1.0
# 2             1.0
# 3            -1.0
# 4             1.0

# %%
train_data.merge(user_sent_bin, how = "inner", left_on="UserId", right_on="UserId")
# Out:
#         Unnamed: 0   ProductId          UserId  Score  \
# 0           333546  B00188S3PM  A3IMFBFX5L85S9      2
# 1           357205  B0006I5M2M  A3IMFBFX5L85S9      2
# 2           503250  B00020HHE0  A3IMFBFX5L85S9      2
# 3           198464  B000FVBYCW  A3IMFBFX5L85S9      2
# 4           352033  B000M0F58U  A3IMFBFX5L85S9      2
# ...            ...         ...             ...    ...
# 397912      332752  B001H9N1B8   ACV9WDT7GVHXP      5
# 397913      370775  B002T165WA  A1QGYBIXWCS9U7      4
# 397914      374564  B002RTEA9O  A1CXHK342D1LE8      5
# 397915      122579  B000CQBZO2  A27UUXC7CANPSV      1
# 397916      305711  B000ELWDV4  A1HDUVAU3426J0      3
#
#                                                      Text  sentiment  \
# 0       I had a hard time drinking this tea as it tast...       -1.0
# 1       I had a hard time drinking this tea as it tast...       -1.0
# 2       I had a hard time drinking this tea as it tast...       -1.0
# 3       I had a hard time drinking this tea as it tast...       -1.0
# 4       I had a hard time drinking this tea as it tast...       -1.0
# ...                                                   ...        ...
# 397912  I have never bought or used food pens before, ...        1.0
# 397913  These crackers are great - they are crispy and...        0.0
# 397914  Walkers pure butter shortbread cookies are the...        1.0
# 397915  I bought these because they advertise this as ...       -1.0
# 397916  Tomato Basil is delicious. Priced a little too...       -1.0
#
#         sentiment_pred  bin_sent
# 0                  1.0         1
# 1                  1.0         1
# 2                  1.0         1
# 3                  1.0         1
# 4                  1.0         1
# ...                ...       ...
# 397912             1.0         5
# 397913             1.0         3
# 397914             1.0         5
# 397915            -1.0         1
# 397916             1.0         1
#
# [397917 rows x 8 columns]
